# %% [markdown]
# # READING ALL DATASETS FILES

# %% [markdown]
# This notebook file is created to read all datasets to know their contents and also use the variables created for each
# file as a stored dataframe to work in other notebooks, to avoid reading in the files all over again.

# %%
#importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import geopandas as gpd
import pysal
from shapely.geometry import Point

# %%
#reading in all files
noise = pd.read_csv('NoiseComplaints.csv')
acorn = pd.read_csv('ACORN.csv')
stop = pd.read_csv('Stops.csv')
df_licenses = pd.read_csv('LiveLicences.csv')
df_license_opening = pd.read_csv('LiveLicenceOpeningTimes.csv')
df_license_activities = pd.read_csv('LiveLicenseActivities.csv')
df_license_appl = pd.read_csv('LicensingApplicaitons.csv')
footfall = pd.read_csv('Footfall.csv')
cleansing = pd.read_csv('Cleansing.csv')
penalties = pd.read_csv('FPNs.csv')
properties = pd.read_csv('PropertyGazetteer.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1,2,5,6,7,9,11,12,13,15,16,20,21,22,23,24,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Storing all dataframes to use in other notebooks

# %%
# %store df_licenses
# Out:
# Stored 'df_licenses' (DataFrame)

# %%
# %store footfall
# Out:
# Stored 'footfall' (DataFrame)

# %%
# %store df_license_activities
# Out:
# Stored 'df_license_activities' (DataFrame)

# %%
# %store properties
# Out:
# Stored 'properties' (DataFrame)

# %%
# %store df_license_opening
# Out:
# Stored 'df_license_opening' (DataFrame)

# %%
# %store noise
# Out:
# Stored 'noise' (DataFrame)

# %%
# %store df_license_appl
# Out:
# Stored 'df_license_appl' (DataFrame)

# %%
# %store cleansing
# Out:
# Stored 'cleansing' (DataFrame)

# %%
# %store penalties
# Out:
# Stored 'penalties' (DataFrame)

# %%
# %store stop
# Out:
# Stored 'stop' (DataFrame)

# %%
#checking contents
noise.head(2)
# Out:
#            UPRN TradingName                                 Address  \
# 0  010033549813         NaN                    Irving Street London
# 1  010033531812         NaN  18A Charing Cross Road London WC2H 0HR
#
#   ServiceRequestGroupSubType                  ServiceRequest  \
# 0                     Street             Noise in the street
# 1        Commercial Premises  Noise from commercial premises
#
#                Street        Ward StressArea        Lat      Long  \
# 0       Irving Street  St James`s   West End  51.509917 -0.128873
# 1  Charing Cross Road  St James`s   West End  51.510536 -0.128199
#
#   ReceivedDate ReceivedDayOfWeek  ReceivedDayOfWeekNumber ReceivedMonth  \
# 0   2015-01-01               Thu                        4           Jan
# 1   2015-01-01               Thu                        4           Jan
#
#    ReceivedYear  ReceivedMonthNumber ReceivedTime ReceivedTimeHourBand  \
# 0          2015                    1        09:58        09:00 - 10:00
# ...

# %%
#counting records
len(noise)
# Out:
# 14716

# %%
#printing dataframe
acorn
# Out:
#              Ward PostcodeSearch        Lat      Long                Category  \
# 0      Abbey Road         NW65JG  51.536423 -0.185838       Rising Prosperity
# 1      Abbey Road         NW65JH  51.536097 -0.186284       Rising Prosperity
# 2      Abbey Road         NW65JJ  51.535724 -0.186025       Affluent Achiever
# 3      Abbey Road         NW65JL  51.535531 -0.186364       Rising Prosperity
# 4      Abbey Road         NW65JN  51.535425 -0.187046       Affluent Achiever
# 5      Abbey Road         NW65JR  51.535530 -0.186869       Rising Prosperity
# 6      Abbey Road         NW65JS  51.534575 -0.187873       Rising Prosperity
# 7      Abbey Road         NW65JT  51.534900 -0.187413       Rising Prosperity
# 8      Abbey Road         NW65JU  51.536572 -0.185645       Rising Prosperity
# 9      Abbey Road         NW80AA  51.535634 -0.181962       Rising Prosperity
# 10     Abbey Road         NW80AB  51.535890 -0.182255       Rising Prosperity
# ...

# %%
#counting records
len(acorn)
# Out:
# 13338

# %%
#checking contents
df_licenses.head(2)
# Out:
#      LicenceNumber  LicenceApplicationKey       TradingName          UPRN  \
# 0  08/08312/LIPDPS                  83789  Zayna Restaurant  1.000230e+11
# 1    08/08403/LIPT                  92505  Westminster Arms  1.000230e+11
#
#                                Address  Postcode             Street  \
# 0  25 New Quebec Street London W1H 7SF   W1H 7SF  New Quebec Street
# 1      9 Storey's Gate London SW1P 3AT  SW1P 3AT      Storey's Gate
#
#                           Ward    StressArea  \
# 0  Bryanston and Dorset Square  Not Recorded
# 1                   St James's  Not Recorded
#
#                             PremisesType ApplicationGroupSubType  IssuedDate  \
# 0                      Type - Restaurant                Premises  18/12/2012
# 1  Type - Public house or pub restaurant                Premises  05/03/2009
#
#               ApplicantName  \
# 0  The Great Mughal Limited
# 1           Mr G H A Barnes
#
# ...

# %%
#counting records
len(df_licenses)
# Out:
# 3438

# %%
#checking contents
df_license_opening.head(2)
# Out:
#             Refval  LicenceApplicationKey              TradingName  \
# 0  06/03226/WCCMAP                 171761        Nell Of Old Drury
# 1  06/03676/WCCMAP                 171500  Sitar Indian Restaurant
#
#            TimePeriod OpenTime CloseTime    TerminalHour TerminalHourGroup  \
# 0    Monday to Sunday    10:00     00:30  00:01 to 01:00    After Midnight
# 1  Monday to Saturday    10:00     00:30  00:01 to 01:00    After Midnight
#
#    Monday  Tuesday  Wednesday  Thursday  Friday  Saturday          Sunday
# 0  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday          Sunday
# 1  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Not Applicable

# %%
#counting records
len(df_license_opening)
# Out:
# 7321

# %%
#checking contents of dataframe
df_license_activities.head(2)
# Out:
#            Refval  LicenceApplicationKey TradingName  \
# 0  16/03358/LIPCH                  75362          14
# 1  16/03358/LIPCH                  75362          14
#
#                 ActivityType                    TimePeriod OpenTime CloseTime  \
# 0     Late Night Refreshment          Thursday to Saturday    23:00     05:00
# 1  Sale by Retail of Alcohol  Sundays before Bank Holidays    20:00     03:00
#
#      TerminalHour TerminalHourGroup  IssuedDate       ...        \
# 0  04:01 to 05:00    After Midnight  05/04/2016       ...
# 1  02:01 to 03:00    After Midnight  05/04/2016       ...
#
#   LNRMaxTerminalHour RegEnt RegEntMaxTerminalHour          Monday  \
# 0                Yes     No                    No  Not Applicable
# 1                 No     No                    No  Not Applicable
#
#           Tuesday       Wednesday        Thursday          Friday  \
# 0  Not Applicable  Not Applicable        Thursday          Friday
# ...

# %%
#counting records
len(df_license_activities)
# Out:
# 25169

# %%
#checking contents of dataframe
df_license_appl.head(2)
# Out:
#      LicenceNumber  LicenceApplicationKey        TradingName          UPRN  \
# 0  16/12878/PREAPM                 158240       Not Recorded  010033635173
# 1  16/00941/PREAPD                 158153  Foleys Restaurant  010033534474
#
#                             Address  Postcode         Street          Ward  \
# 0  22 Floral Street London WC2E 9DS  WC2E 9DS  Floral Street  Not Recorded
# 1    23 Foley Street London W1W 6DU   W1W 6DU   Foley Street      West End
#
#      StressArea  PremisesType ApplicationGroupSubType  IssuedDate        Lat  \
# 0      West End  Not Recorded                 Pre-App  1900-01-01  51.511919
# 1  Not Recorded  Not Recorded                 Pre-App  1900-01-01  51.519373
#
#        Long      Capacity      Decision                status
# 0 -0.125275  Not Recorded  Not Recorded      Pending Decision
# 1 -0.140492  Not Recorded  Not Recorded  Application received

# %%
#counting records
len(df_license_appl)
# Out:
# 4707

# %%
#checking contents of dataframe
footfall.head(2)
# Out:
#       DataOwner                 Site            Location        Date  \
# 0  Spring Board  Heart of London BID  Shaftesbury Avenue  2016-02-05
# 1  Spring Board  Heart of London BID  Shaftesbury Avenue  2016-02-01
#
#   DayOfWeek  DayOfWeekNumber Month  MonthNumber  Year  Week   Time  \
# 0       Fri                5   Feb            2  2016  WK06  00:00
# 1       Mon                1   Feb            2  2016  WK06  00:00
#
#         HourBand  Lat  Long        Street          Ward    StressArea  \
# 0  00:00 - 01:00 -1.0  -1.0  Not Recorded  Not Recorded  Not Recorded
# 1  00:00 - 01:00 -1.0  -1.0  Not Recorded  Not Recorded  Not Recorded
#
#    InCount  OutCount  ReportCount
# 0      296       188          484
# 1      181       155          336

# %%
#counting records
len(footfall)
# Out:
# 700248

# %%
#printing dataframe
cleansing
# Out:
#        EventID             Street          Ward    StressArea        Lat  \
# 0      1828256  Kilburn Park Road       Kilburn  Not Recorded  51.532165
# 1      1828258  Kilburn Park Road       Kilburn  Not Recorded  51.532165
# 2      1861071       Carlton Vale       Kilburn  Not Recorded  51.532148
# 3      1943021       Carlton Vale       Kilburn  Not Recorded  51.532148
# 4      3134142       Carlton Vale       Kilburn  Not Recorded  51.532148
# 5      1719617       Not Recorded       Kilburn  Not Recorded  51.533892
# 6      1725105       Not Recorded       Kilburn  Not Recorded  51.533892
# 7      1836255       Not Recorded       Kilburn  Not Recorded  51.533892
# 8      1965949       Not Recorded       Kilburn  Not Recorded  51.533892
# 9      2949027       Not Recorded       Kilburn  Not Recorded  51.533892
# 10     3032545       Not Recorded       Kilburn  Not Recorded  51.533892
# 11     2968537       Not Recorded       Kilburn  Not Recorded  51.533892
# ...

# %%
#counting records
len(cleansing)
# Out:
# 71074

# %%
#checking contents of dataframe
penalties.head(2)
# Out:
#   TradingName                           ServiceRequest         Street  \
# 0         NaN  Street Litter Ticket - Commercial (�50)   Wells Street
# 1         NaN  Street Litter Ticket - Commercial (�50)  Covent Garden
#
#          Ward StressArea        Lat      Long ReceivedDate ReceivedDayOfWeek  \
# 0    West End   West End  51.516602 -0.137578   2015-01-05               Mon
# 1  St James`s   West End  51.511998 -0.121798   2015-01-05               Mon
#
#    ReceivedDayOfWeekNumber ReceivedMonth  ReceivedYear  ReceivedMonthNumber  \
# 0                        1           Jan          2015                    1
# 1                        1           Jan          2015                    1
#
#   ReceivedTime ReceivedTimeHourBand   ContactMethod
# 0        09:50        09:00 - 10:00  Self Generated
# 1        12:17        12:00 - 13:00  Self Generated

# %%
#counting records
len(penalties)
# Out:
# 7662

# %%
#checking contents of dataframe
properties.head(1)
# Out:
#           UPRN                             Address Postcode StreetName  \
# 0  10033527075  Flat 1 24 Hill Road London NW8 9QG  NW8 9QG  Hill Road
#
#   PropertyType PrimaryClassification SecondaryClassification      Borough  \
# 0     Property           Residential               Dwellings  Westminster
#
#         Lat      Long
# 0  51.53203 -0.180347

# %%
#counting records
len(properties)
# Out:
# 180497

# %%
#printing dataframe
stop
# Out:
#             ATCOCode NaptanCode PlateCode  CleardownCode  \
# 0       0100BRP90207    bstmdat       NaN            NaN
# 1       0100BRP90210    bstjwgd       NaN            NaN
# 2       0100BRP90080    bstjagp       NaN            NaN
# 3       0100BRP90081    bstgwgj       NaN            NaN
# 4       0100BRP90082    bstgwgd       NaN            NaN
# 5       0100BRA56555    bstpawm       NaN            NaN
# 6       0100BRA56556    bstpawp       NaN            NaN
# 7       0100BRA56557    bstpawt       NaN            NaN
# 8       0100BRA56568    bstpdgm       NaN            NaN
# 9       0100BRP90097    bstjgtw       NaN            NaN
# 10      0100BRP90135    bstjmgt       NaN            NaN
# 11      0100BRA10919    bstmgtw       NaN            NaN
# 12      0100BRA10922    bstmgmt       NaN            NaN
# 13      0100BRA10923    bstmgmw       NaN            NaN
# 14      0100BRP90098    bstjmjp       NaN            NaN
# ...

# %%
#counting records
len(stop)
# Out:
# 429845
